# %% [markdown]
# ### Exercise 5: Subplot Layout

# %%
# TASK: Create a 2x2 subplot layout.
# Plot a line chart in the first subplot, a bar chart in the second, a scatter plot in the third, and a pie chart in the fourth.

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2, 2, figsize=(10, 8))


x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]
axs[0, 0].plot(x, y, color='blue', marker='o')
axs[0, 0].set_title('Line Chart')


categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]
axs[0, 1].bar(categories, values, color=['red', 'green', 'blue', 'purple'])
axs[0, 1].set_title('Bar Chart')

x_scatter = [1, 2, 3, 4, 5]
y_scatter = [2, 4, 6, 8, 10]
axs[1, 0].scatter(x_scatter, y_scatter, color='orange')
axs[1, 0].set_title('Scatter Plot')

labels = ['Python', 'Java', 'C++', 'JavaScript']
sizes = [40, 25, 20, 15]  # You had only 3 values before; added one to match 4 labels
axs[1, 1].pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
axs[1, 1].set_title('Pie Chart')
axs[1, 1].axis('equal')  # Equal aspect ratio ensures pie is drawn as a circle

plt.tight_layout()

plt.show()
